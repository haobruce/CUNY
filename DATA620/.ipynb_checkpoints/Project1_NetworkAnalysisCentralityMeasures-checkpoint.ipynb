# %% [markdown]
# DATA 620
# Bruce Hao
# Project 1
#
# For Project 1, I built a simple websraper to look at social network data on Facebook. I applied the snowball method starting with one central node and went three layers deep. I sampled just the first page of friends for each node to keep things manageable. I then trimmed the graph for nodes with less than 10 degrees and then gathered attribute data for the remaining nodes. Right before this final stage, my account got temporarily blocked (too much testing!), so I'm not sure if I'll have the attribute data in time for submission.

# %%
# %matplotlib inline
import os
import networkx as net
import pandas as pd

# %%
# load network graph data and show graph 
g = net.read_pajek(os.getcwd() + '/_data/facebook_network.net')

def show_network(g3):
    pos = net.spring_layout(g3)
    net.draw_networkx_nodes(g3, pos, alpha=0.5)
    net.draw_networkx_edges(g3, pos, alpha=0.5)
    net.draw_networkx_labels(g3, pos, alpha=0.7)

show_network(g)

# %%
# compute centrality measures: degree, closeness, betweenness and eigenvector closeness

# %%
# degree
d = net.degree(g)
ds = sorted(g.degree, key=lambda x: x[1], reverse=True)
ds[:10]
# Out:
# [('profile.php', 65),
#  ('chuck.pyle.71', 57),
#  ('tien.luu.984', 52),
#  ('quangminh.trieu.3', 49),
#  ('mariliawonka', 49),
#  ('seonghyodamiane.cho', 46),
#  ('joko.budiono.908', 46),
#  ('ryan.winch.12', 43),
#  ('dax.santi', 43),
#  ('spicysilence', 41)]

# %%
# closeness 
c = net.closeness_centrality(g)
cs = sorted_map(c)
cs[:10]
# Out:
# [('profile.php', 0.773109243697479),
#  ('chuck.pyle.71', 0.7244094488188977),
#  ('tien.luu.984', 0.696969696969697),
#  ('quangminh.trieu.3', 0.6814814814814815),
#  ('mariliawonka', 0.6814814814814815),
#  ('seonghyodamiane.cho', 0.6666666666666666),
#  ('joko.budiono.908', 0.6666666666666666),
#  ('ryan.winch.12', 0.6524822695035462),
#  ('dax.santi', 0.6524822695035462),
#  ('spicysilence', 0.6433566433566433)]

# %%
# betweenness 
b = net.betweenness_centrality(g)
bs = sorted_map(b)
bs[:10]
# Out:
# [('profile.php', 0.1107443341732942),
#  ('chuck.pyle.71', 0.035309706554985026),
#  ('lu.sa.3382', 0.02980433993831107),
#  ('tien.luu.984', 0.02945447176901543),
#  ('quangminh.trieu.3', 0.024306004178201994),
#  ('seonghyodamiane.cho', 0.02252237024391323),
#  ('joko.budiono.908', 0.021929514740285948),
#  ('ryan.winch.12', 0.02019134614739093),
#  ('mariliawonka', 0.019362175763636812),
#  ('kiarash.motamedi', 0.01598794748585837)]

# %%
e = net.eigenvector_centrality_numpy(g)
ec = sorted_map(e)
ec[:10]
# Out:
# [('profile.php', 0.20496860706729222),
#  ('chuck.pyle.71', 0.20069109760250942),
#  ('mariliawonka', 0.18131739800996063),
#  ('tien.luu.984', 0.17971892628573763),
#  ('quangminh.trieu.3', 0.17404244474300826),
#  ('joko.budiono.908', 0.16300124882230455),
#  ('seonghyodamiane.cho', 0.16128571396731062),
#  ('djonesmaster', 0.158263577747421),
#  ('dax.santi', 0.15699469350741244),
#  ('gerry.selian', 0.15216836976941445)]

# %%
# print table of users with highest centrality measures 
names1=[x[0] for x in ds[:10]]
names2=[x[0] for x in cs[:10]]
names3=[x[0] for x in bs[:10]]
names4=[x[0] for x in ec[:10]]
names=list(set(names1) | set(names2) | set(names3) | set(names4))
table=[[name, d[name], c[name], b[name], e[name]] for name in names]
df = pd.DataFrame(table, columns=['user_name','degree','closeness','betweenness','eigenvector'])

# sum ranks to order by centrality - assumes equal weighting 
df['rank'] = df.rank(axis=0, ascending=False).sum(axis=1)
# df.drop('user_name', axis=1, inplace=True)  
df.sort_values(by=['rank'])
# Out:
#               user_name  degree  closeness  betweenness  eigenvector  rank
# 8           profile.php      65   0.773109     0.110744     0.204969  10.0
# 7          tien.luu.984      52   0.696970     0.029454     0.179719  15.0
# 6         chuck.pyle.71      57   0.724409     0.035310     0.200691  22.0
# 1     quangminh.trieu.3      49   0.681481     0.024306     0.174042  24.0
# 5          mariliawonka      49   0.681481     0.019362     0.181317  28.0
# 13  seonghyodamiane.cho      46   0.666667     0.022522     0.161286  29.0
# 12     joko.budiono.908      46   0.666667     0.021930     0.163001  36.0
# 0         ryan.winch.12      43   0.652482     0.020191     0.147510  41.0
# 9          spicysilence      41   0.643357     0.012903     0.151974  46.0
# 10            dax.santi      43   0.652482     0.014775     0.156995  50.0
# 11           lu.sa.3382      36   0.621622     0.029804     0.111415  53.0
# 2          djonesmaster      41   0.643357     0.011054     0.158264  55.0
# 3          gerry.selian      40   0.638889     0.012338     0.152168  58.0
# 4      kiarash.motamedi      37   0.625850     0.015988     0.124953  58.0
